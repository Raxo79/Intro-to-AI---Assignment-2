# %%
import pandas as panda
from sklearn import linear_model
import matplotlib.pyplot as plt

# %%
dataset = panda.read_csv('Ruter-data.csv', sep=";")
dataset
# Out:
#                                 TurId        Dato  Fylke    Område  \
# 0     15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken      Vest
# 1     15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken      Vest
# 2     15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken      Vest
# 3     15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 4     15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken      Vest
# ...                               ...         ...    ...       ...
# 5995  10001-2020-06-10T15:10:00+02:00  10/06/2020  Viken   Nordøst
# 5996  10010-2020-06-23T05:54:00+02:00  23/06/2020  Viken   Nordøst
# 5997   2007-2020-06-11T17:22:00+02:00  11/06/2020   Oslo  Indre By
# 5998  10004-2020-08-13T04:59:00+02:00  13/08/2020   Oslo  Indre By
# 5999  34013-2020-08-05T13:31:00+02:00  05/08/2020  Viken   Nordøst
#
#          Kommune                          Holdeplass_Fra  \
# 0          Bærum                             Nordliveien
# ...

# %%
input = dataset.drop('Passasjerer_Ombord', axis='columns')
input.head(20)
# Out:
#                               TurId        Dato  Fylke    Område  \
# 0   15006-2020-08-10T10:24:00+02:00  10/08/2020  Viken      Vest
# 1   15002-2020-08-15T12:54:00+02:00  15/08/2020  Viken      Vest
# 2   15004-2020-08-03T09:54:00+02:00  03/08/2020  Viken      Vest
# 3   15003-2020-07-27T13:00:00+02:00  27/07/2020  Viken      Vest
# 4   15002-2020-08-27T07:15:00+02:00  27/08/2020  Viken      Vest
# 5    3110-2020-08-01T16:16:00+02:00  01/08/2020   Oslo   Nordøst
# 6   15010-2020-07-28T13:09:00+02:00  28/07/2020  Viken      Vest
# 7   15003-2020-07-27T06:18:00+02:00  27/07/2020   Oslo  Indre By
# 8   21002-2020-08-16T14:33:00+02:00  16/08/2020  Viken      Vest
# 9   15002-2020-08-13T18:09:00+02:00  13/08/2020  Viken      Vest
# 10  49005-2020-06-23T21:30:00+02:00  23/06/2020  Viken       Sør
# 11  21005-2020-08-17T17:55:00+02:00  17/08/2020  Viken      Vest
# 12   3105-2020-07-27T00:16:00+02:00  26/07/2020   Oslo  Indre By
# ...

# %%
#input = dataset.drop('TurId', axis='columns')
#input.head(20)

# %%
Dato_float = dataset['Dato'].replace("/","", regex=True).astype(float)
Dato_float
# Out:
# 0       10082020.0
# 1       15082020.0
# 2        3082020.0
# 3       27072020.0
# 4       27082020.0
#            ...
# 5995    10062020.0
# 5996    23062020.0
# 5997    11062020.0
# 5998    13082020.0
# 5999     5082020.0
# Name: Dato, Length: 6000, dtype: float64

# %%
Linjenavn = dataset.Linjenavn
Linjenavn
# Out:
# 0       150
# 1       150
# 2       150
# 3       150
# 4       150
#        ...
# 5995    100
# 5996    100
# 5997     20
# 5998    100
# 5999    340
# Name: Linjenavn, Length: 6000, dtype: object

# %%
#dato_string = dataset.dato
#dato_float = float(dato_string)

# %%
antallPassasjerer = dataset.Passasjerer_Ombord
antallPassasjerer
# Out:
# 0        5
# 1        5
# 2        6
# 3       10
# 4       10
#         ..
# 5995     2
# 5996     2
# 5997     3
# 5998     5
# 5999    -5
# Name: Passasjerer_Ombord, Length: 6000, dtype: int64

# %%
#Dato_float = dataset['Dato'].replace("/","", regex=True).astype(float)

regObj = linear_model.LinearRegression()
regObj.fit(input,antallPassasjerer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-99-52018beae24e> in <module>
#       2
#       3 regObj = linear_model.LinearRegression()
# ----> 4 regObj.fit(input,antallPassasjerer)
#
# C:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     503
#     504         n_jobs_ = self.n_jobs
# --> 505         X, y = self._validate_data(X, y, accept_sparse=['csr', 'csc', 'coo'],
#     506                                    y_numeric=True, multi_output=True)
#     507
#
# C:\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     430                 y = check_array(y, **check_y_params)
#     431             else:
# --> 432                 X, y = check_X_y(X, y, **check_params)
#     433             out = X, y
#     434
#
# ...
